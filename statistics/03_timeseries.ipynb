# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

years = pd.period_range("1994", "2001", freq="Y")
RowA = [120, 150, 170, 200, 160, 190, 240, 260]
RowB = [80, 130, 150, 160, 210, 220, 190, 200]
table = pd.DataFrame({"Reihe A": RowA, "Reihe B": RowB}, index=years)

plt.figure()
table.plot()

print(table)
# Out:
#       Reihe A  Reihe B
# 1994      120       80
# 1995      150      130
# 1996      170      150
# 1997      200      160
# 1998      160      210
# 1999      190      220
# 2000      240      190
# 2001      260      200
